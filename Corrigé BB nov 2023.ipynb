# %% [markdown]
# # CORRECTION BB NOV 2023
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 1. $u_1 = 0,9 \times 1000 + 250 = 900 + 250 = 1150$
#
# #### 2.    $ u_{n+1}=0,9u_n+250$
# avec  $u_{n+1}$ le nombre d'abonnés en $2020+n+1 $
#   0,9 traduit la diminution de $10%$
#   $u_n$ traduit le nombre d'abonnés en $2020+n$
#   $+250$ car chaque année, elle gagne 250 abonnés suppémentaires.
#
# #### 3.      suite(10) appelle la fonction suite avec comme paramètre n=10.
# n donne le nombre de fois où la boucle "for" est utilisée.
# u = 1000 à l'initial.
# La relation de récurrence $u=0.9*u+250$ est réalisée 10 fois.
# ainsi on obtient la valeur du terme $u_{10}$
#
#
# $---------------------------------------$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 4.a.
# On cherche à vérifier que $"u_n \le 2500"$  .
#
# Pour $n=0$, $u_0=1000$. Ainsi $u_0 \le 2500$.
# $P_0$ est vérifiée.
#
# On suppose que $P_n$ est vraie pour un rang $n$ donné, vérifions que cela implique que $P_{n+1}$ est vraie. C'est-à-dire que : $u_n \le 2500 \iff u_{n+1}\le 2500$
#
# $$\begin{array} \\
# u_n &\le& 2500 \\
# 0,9u_n &\le& 2250 \\
# 0,9u_n+250 &\le& 2500\\
# u_{n+1} &\le& 2500\\
# \end{array}$$
#
# Donc $P_n$ est héréditaire.
#
# Comme $P_n$ est initialisée au rang 0 et héréditaire alors $P_n$ est vraie pour tout $n\in \mathbb{N}$
#
# #### 4.b.
#
# $(U_n)$ est croissante ssi $u_{n+1}-u_n \gt 0$.
#
# $$\begin{array} \\
# \quad \quad u_{n+1}-u_n &\gt& 0  \\
# \iff 0,9u_n+250 - u_n &\gt& 0 \\
# \iff -0,1u_n+250 &\gt&0 \\
# \iff -0,1u_n &\gt& -250 \\
# \iff u_n &\lt& 2500 \\
# \end{array} $$
# Or $u_n \lt 2500$ est vraie pour tout $n\in\mathbb{N}$ ce qui équivaut à dire que $(U_n)$ est croissante pour tout $n\in \mathbb{N}$.
#
# #### 4.c.
# Question facultative:
# Comme $(u_n)$ est croissante et majorée alors elle est convergente.
#
# $---------------------------------------$

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### 5.a.
# $(v_n)$ est une suite géométrique si et seulement si $v_{n+1} = qv_n$ avec $q \in \mathbb{R}$.
# On cherche à exprimer $v_{n+1}$:
# $$\begin{array}\\
# v_{n+1} &=& u_{n+1}-2500 \\
# v_{n+1} &=& 0,9\times u_n +250 -2500 \\
# &=& 0,9u_n-2250 \\
# &=& 0,9(u_n - 2500)\\
# v_{n+1}&=& 0,9 v_n\\
# \end{array}$$
# Donc $(v_n)$ est  géométrique de raison $0,9$ et de premier terme $v_0=u_0-2500=-1500$
#
#  #### 5b.
# $(v_n)$ est géométrique donc $v_n=v_0 \times q^n$.
#
# $v_n=-1500 \times (0,9)^n$  et comme $u_n = v_n +2500$
#
#
# $u_n= - 1500 \times 0,9^n +2500 $
#
# #### 5c.  question facultative
# $\lim \limits_{n \to =\infty} 0,9^n = 0$ d'où $\lim\limits_{n \to +\infty} -1500 \times 0,9^n = 0$
#
# Au final: $\lim \limits_{n \to +\infty} u_n = 2500$

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def seuil():
    n = 0
    u = 1000
    while u <= 2200:
        n = n +1
        u = 0.9 * u + 250
    return n+2020

# %%
seuil()
# Out:
# 2036

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.b.
#
# $$\begin{array} \\
# P(M \cap T) &=& P(M) \times P_M(T) \\
# &=& 0,4 \times 0,9 \\
# &=& 0,36 \\
# \end{array}$$
#
# #### 1.c.
#
# Il s'agit d'une probabilité totale:
# $$\begin{array} \\
# P(T) &=& P(M \cap T) + P(\overline{M} \cap T) \\
# &=& P(M)P_M(T) + P(\overline{M})P_{\overline{M}}(T) \\
# &=& 0,4 \times 0,9 + 0,6 \times 0,15 \\
# &=& 0,36 + 0,09 \\
# &=& 0,45
# \end{array}$$
#
#
# #### 1.d.
# On sait que le test est positif et on cherche la probabilité qu'il soit malade.
# $$ \begin{array} \\
# P_T(M) &=& \dfrac{P(T \cap M)}{P(T)}\\
# P_T(M) &=& \dfrac{0,36}{0,45} \\
# P_T(M) &=& 0,8
# \end{array}$$
#
#
# Si le test est positif alors il y a 80% de chance qu'il soit malade.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2.a.
# X est la variable aléatoire donnant le nombre de chats ayant un test positif.
# L'expérience "choisir un chat " est un schéma de Bernoulli ayant deux issues: test positif (succès avec p = 0,45) et test négatif (échec).
# Cette expérience est répétée 20 fois de manière identique et indépendante.
# Alors X suit une loi binomiale de paramètres n=20 et p = 0,45.
#
# #### 2.b.
# $$P(X = k) = \pmatrix{20 \\ k}(0,45)^k(0,55)^{20-k}$$
#
# $$\begin{array} \\
# P(X=5) &=& \pmatrix{20 \\ 5}(0,45)^5(0,55)^{15} \\
# \\
# P(X=5) &=& 0,036
# \end{array}
# $$
#
# #### 2.c.
# La probabilité qu'il y ait au plus 8 chats dont le test est positif.
#
# $$\begin{array} \\
# P(X\le 8) &=& P(X=0) + P(X=1) + \ldots  + P(X=7) + P(X=8)  \\
# &\approx & 0,414
# \end{array}$$
#
# #### 2.d.
# L'espérance de X suivant la loi binomiale est $E(X)= np$.
# $E(X)= 20 \times 0,45= 9$
#
# Sur un grand nombre de centre et d'expériences, on peut estimer que 9 chats en moyenne auront un test positif.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.
# $f'(x)= (x)'(e^{-2x})+x(e^{-2x})' = e^{-2x}-2xe^{-2x} = e^{-2x}(1-2x)$
# réponse a.
#
# #### 2.
# $\pmatrix{12 \\ 3} = 220$
# réponse c.
#
# #### 3.
# réponse b.
#
# ![image.png](attachment:image.png)
# #### 4.
#
# $P(A \cap B) = P(A) + P(B) -P(A \cup B) $
#
# or $P(A \cup B) = 1 - P(\overline{A} \cap \overline{B})$
#
# donc
# $P(A \cap B) = P(A) + P(B) -1 +P(\overline{A} \cap \overline{B}) $
# $P(A \cap B) = 0,028 + 0,022 -1 + 0,954$
# $P(A \cap B) = 0,004$
# soit 0,4 %.
# réponse b.
#
# ![image-2.png](attachment:image-2.png)
#
# #### 5.
# réponse b.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 1.
# à ne pas faire.
# #### 2.
# Pour étudier les variation de h, nus devons trouver la fonction dérivée de h.
#
# $h$ est une fonction somme de $e^x$ définie et dérivable sur $\mathbb{R}$ et $-x$ définie et dérivable sur $\mathbb{R}$ . Ainsi h est dérivable sur $\mathbb{R}$.
#
#
# $$ h'(x)= e^x -1$$
#
# On étudie le signe de h:
# $$\begin{array} \\
# \quad h'(x) &>& 0 \\
#  \iff e^x-1 &>& 0 \\
#  \iff e^x &>& 1 \\
#  \iff e^x &>& e^0 \\
#  \iff x &>& 0
#  \end{array}$$
#  Donc sur $]-\infty;0] , h'(x)<0 \mbox{ et sur } [0;+\infty[, h'(x)>0$  .
#
#  On en conclut que sur $]-\infty;0]$ h est décroissante et que sur $[0;+\infty[$ h est croissante.
#
#  #### 3.
# h est croissante sur  $[0;+\infty[$ alors pour a et b réels tels que:
# $0<a<b$ alors $0<h(a)<h(b)$ ce qui peut s'écrire:
# $0<a<b$ alors $h(a)- h(b) < 0$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## B.
# #### 1.
# une équation de $T_0$ est :
# $$T_0: \quad y= f'(0)(x-0)+f(0)$$
#
# avec $f(x) = e^x$ , dérivable sur $\mathbb{R}$  et $f'(x) = e^x$.
# $$T_0: \quad y= e^0 x + e^0$$
# $$T_0 \quad y=x+1$$

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 2. à ne pas faire
# #### 3.a.
# On sait que :
# $$u_n=exp\big(\dfrac{1}{n}\big)-\dfrac{1}{n}-1$$
#
# Par analogie:
# $$u_{n+1} = exp\big(\dfrac{1}{n+1}\big)-\dfrac{1}{n+1}-1$$
#
#  Puis on soustrait:
#  $$\begin{array}\\
#  u_{n+1}-u_n &=& exp\big(\dfrac{1}{n+1}\big)-\dfrac{1}{n+1}-1 -\Bigg(exp\big(\dfrac{1}{n}\big)-\dfrac{1}{n}-1\Bigg) \\
#  &=& h\Bigg(\dfrac{1}{n+1}\Bigg) - h\Bigg(\dfrac{1}{n}\Bigg)
#  \end{array}$$
#
# #### 3.b.
# Or nous avions vu précédemment que :
# $0<a<b$ alors $h(a)- h(b) < 0$
# ici $a= \dfrac{1}{n+1}$ et $b= \dfrac{1}{n}$
# et on a bien:
# $0<\dfrac{1}{n+1}<\dfrac{1}{n}$ alors on peut en déduire que $h\bigg(\dfrac{1}{n+1}\Bigg)- h\Bigg(\dfrac{1}{n}\Bigg) < 0$
# ce qui équivaut à dire que $u_{n+1}-u_n<0$, et donc que $(u_n)$ st décroissante pour tout $n\in \mathbb{N}$.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# $$u_n=exp\big(\dfrac{1}{n}\big)-\dfrac{1}{n}-1$$
# $$u_n=f(n)-T_0$$
#
# Ici l'écart entre $\mathcal{C_f}$ et $T_0$ correspond à la valeur du terme $u_n$. Donc pour un écart inférieur à $10^{-2}$ on voit que $u_8<10^{-2}$. Donc à partir du rang 8.
